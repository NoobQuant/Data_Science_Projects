# %% [markdown]
# # Introduction to SOM in R
# This is an introduction to SOM. Original example courtesy of Shane Lynn.
#
# https://www.shanelynn.ie/self-organising-maps-for-customer-segmentation-using-r/
#
# https://github.com/shanealynn/Kohonen-Self-organising-maps-in-R/
#
# https://github.com/opetchey/RREEBES/wiki/Reading-data-and-code-from-an-online-github-repository

# %%
.libPaths()
# Out:
# [1] "C:/Users/ville_000/Documents/R/win-library/3.4"
# [2] "C:/Users/ville_000/Anaconda3/envs/mro_env/lib/R/library"

# %%
# Example for downloading a package
#install.packages('rgdal', repos='http://cran.us.r-project.org')

# %%
require(kohonen)
#require(RCurl)
require(rgeos)
require(rgdal)
# Out:
# Loading required package: kohonen
# Warning message:
# "package 'kohonen' was built under R version 3.4.4"Loading required package: rgeos
# Warning message:
# "package 'rgeos' was built under R version 3.4.4"rgeos version: 0.3-28, (SVN revision 572)
#  GEOS runtime version: 3.6.1-CAPI-1.10.1 r0
#  Linking to sp version: 1.3-1
#  Polygon checking: TRUE
#
# Loading required package: rgdal
# Warning message:
# "package 'rgdal' was built under R version 3.4.4"Loading required package: sp
# Warning message:
# "package 'sp' was built under R version 3.4.4"rgdal: version: 1.3-4, (SVN revision 766)
#  Geospatial Data Abstraction Library extensions to R successfully loaded
#  Loaded GDAL runtime: GDAL 2.2.3, released 2017/11/20
#  Path to GDAL shared files: C:/Users/ville_000/Documents/R/win-library/3.4/rgdal/gdal
#  GDAL binary built with GEOS: TRUE
#  Loaded PROJ.4 runtime: Rel. 4.9.3, 15 August 2016, [PJ_VERSION: 493]
#  Path to PROJ.4 shared files: C:/Users/ville_000/Documents/R/win-library/3.4/rgdal/proj
#  Linking to sp version: 1.3-1

# %%
# Load data
data_raw = read.csv("./census_data/AllThemesTablesSA.csv")
data_raw_safe = data_raw
head(data_raw)

# Join map data
ireland_map = readOGR('./boundary_files/Census2011_Small_Areas_generalised20m.shp', encoding = 'utf8')
#Note that the map polygons and the census data are not in the same order - rearrangement:
data_raw = data_raw[match(ireland_map$SMALL_AREA, data_raw$GEOGDESC),]
idcol="GEOGDESC"

# Filter for Dublin areas
counties = c("Fingal", "Dublin City", "South Dublin", "Dn Laoghaire-Rathdown")
plot_idx = ireland_map$COUNTYNAME %in% counties
data_raw = data_raw[plot_idx,]
ireland_map = ireland_map[plot_idx,]
# Out:
#   ï..GEOGID  GEOGTYPE GEOGDESC  T1_1AGE0M T1_1AGE1M T1_1AGE2M T1_1AGE3M
# 1 A017001001 SA       017001001 6         5         6         5
# 2 A017002001 SA       017002001 2         2         3         2
# 3 A017002002 SA       017002002 3         2         0         1
# 4 A017002003 SA       017002003 1         0         1         2
# 5 A017003001 SA       017003001 1         2         4         3
# 6 A017003002 SA       017003002 1         2         2         1
#   T1_1AGE4M T1_1AGE5M T1_1AGE6M ... T15_1_GE4C T15_2_Y T15_2_N T15_2_NS T15_2_T
# 1 4         2         4         ... 5           93     28      2        123
# 2 3         5         2         ... 4           83     24      1        108
# 3 2         2         7         ... 3          109     23      3        135
# 4 1         0         0         ... 8           86     16      2        104
# 5 0         2         2         ... 3           57     20      1         78
# 6 3         4         2         ... 5           80     28      0        108
#   T15_3_B T15_3_OTH T15_3_N T15_3_NS T15_3_T
# 1 70      22        30      1        123
# 2 64      19        25      0        108
# 3 93      14        24      4        135
# 4 77      10        15      2        104
# 5 41       8        26      3         78
# 6 66      11        30      1        108
# OGR data source with driver: ESRI Shapefile
# Source: "D:\Dropbox\Data_Science_Projects\kdd\SOM_in_R\boundary_files\Census2011_Small_Areas_generalised20m.shp", layer: "Census2011_Small_Areas_generalised20m"
# with 18488 features
# It has 21 fields

# %% [markdown]
# ## Data preprocessing

# %%
#convert the data from summations to percentages such 
#that the characteristics of each area will be comparable.
source("convertCSOdata.R")
data = convertCSOdata(data_raw, idcol=idcol)

incompletes = which(!complete.cases(data))
data$avr_education_level[incompletes] <- mean(data$avr_education_level, na.rm=TRUE)
#recalculate after adjustment
incompletes <- which(!complete.cases(data))
if (length(incompletes) > 0){
  print(paste0("Removing ", length(incompletes), " data points that have missing values."))
  data <- data[-incompletes, ]
}

# %%
head(data)
dim(data)
# Out:
#       id        avr_age  avr_household_size avr_education_level avr_num_cars
# 15687 267123023 40.02811 2.524752           3.038462            1.039604
# 13895 267016001 35.67366 3.320611           3.597701            1.983740
# 13896 267016002 35.88235 3.324324           4.295302            1.905405
# 13729 267002034 38.51667 3.088608           3.871795            1.730769
# 13724 267002029 24.67800 3.512000           3.933735            1.112000
# 13739 267002044 25.13953 3.136364           4.496855            1.109091
#       avr_health rented_percent unemployment_percent internet_percent
# 15687 4.385542    6.930693      15.343915            71.00000
# 13895 4.509434    4.878049      12.461059            72.95082
# 13896 4.596639    1.351351      10.404624            83.78378
# 13729 4.530172    3.896104       8.108108            78.94737
# 13724 4.510345   20.800000      21.810700            81.30081
# 13739 4.419162   29.357798      24.154589            81.90476
#       single_percent married_percent separated_percent divorced_percent
# 15687 53.41365       33.33333        4.8192771         2.8112450
# 13895 49.41725       44.98834        1.3986014         0.2331002
# 13896 47.47899       43.69748        3.3613445         0.0000000
# 13729 47.08333       48.33333        0.8333333         1.2500000
# 13724 67.12018       26.98413        2.2675737         1.5873016
# 13739 64.24419       30.23256        1.4534884         3.4883721
#       widow_percent
# 15687 5.6224900
# 13895 3.9627040
# 13896 5.4621849
# 13729 2.5000000
# 13724 2.0408163
# 13739 0.5813953
# [1] 4046   14

# %%
write.csv(data, file = "data_from_R.csv")

# %% [markdown]
# ## SOM training

# %%
# Select data for train
data_train = data[, c(2,4,5,8)]

# now train the SOM using the Kohonen method
data_train_matrix = as.matrix(scale(data_train))
names(data_train_matrix) = names(data_train)

# larger grid for the small areas example (more samples)
som_grid = somgrid(xdim = 20, ydim=20, topo="hexagonal")  

# Train the SOM model!
som_model = som(data_train_matrix, 
                grid=som_grid, 
                rlen=500, 
                alpha=c(0.1,0.01), 
                keep.data = TRUE )

# %%
head(data_train)
# Out:
#       avr_age  avr_education_level avr_num_cars unemployment_percent
# 15687 40.02811 3.038462            1.039604     15.343915
# 13895 35.67366 3.597701            1.983740     12.461059
# 13896 35.88235 4.295302            1.905405     10.404624
# 13729 38.51667 3.871795            1.730769      8.108108
# 13724 24.67800 3.933735            1.112000     21.810700
# 13739 25.13953 4.496855            1.109091     24.154589

# %%
## custom palette as per kohonen package (not compulsory)
source('coolBlueHotRed.R')
plot(som_model, type = "changes")
# Out:
# Plot with title "Training progress"

# %%
plot(som_model, type = "counts", main="Node Counts", palette.name=coolBlueHotRed)
# Out:
# plot without title

# %%
plot(som_model, type="dist.neighbours", main = "SOM neighbour distances")
# Out:
# plot without title

# %%
plot(som_model, type="codes")
# Out:
# Plot with title "Codes plot"

# %%
var = 3
var_unscaled = aggregate(as.numeric(data_train[,var]), by=list(som_model$unit.classif), FUN=mean, simplify=TRUE)[,2]
plot(som_model, type = "property", property=var_unscaled, main=names(data_train)[var], palette.name=coolBlueHotRed)
# Out:
# plot without title

# %%
mydata <- getCodes(som_model)
wss <- (nrow(mydata)-1)*sum(apply(mydata,2,var))
for (i in 2:15) wss[i] <- sum(kmeans(mydata,
                                     centers=i)$withinss)
par(mar=c(5.1,4.1,4.1,2.1))
plot(1:15, wss, type="b", xlab="Number of Clusters",
     ylab="Within groups sum of squares", main="Within cluster sum of squares (WCSS)")
# Out:
# Plot with title "Within cluster sum of squares (WCSS)"
